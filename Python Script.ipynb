# %% [markdown]
# # Data Extraction and Loading Documentation
#
# This documentation provides an overview of the data extraction from AWS S3 bucket and loading into Postgres process using the provided Jupyter Notebook script.
#
# ## Modules
#
# The following modules are imported for data extraction and loading:

# %%
# To import all the modules for data extraction and loading
import boto3
from botocore import UNSIGNED
from botocore.client import Config
import csv
import psycopg2
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %% [markdown]
# # Data Extraction
#
# The data extraction process involves downloading CSV files from an S3 bucket using the Boto3 library. The script downloads the following files: orders.csv, reviews.csv, and shipment_deliveries.csv.
#
# ## The script uses the following parameters:
#
# * bucket_name: The name of the S3 bucket.
# * file_names: A list of file names to download.

# %%
#Specifying a few parameters
bucket_name = "d2b-internal-assessment-bucket"
file_names = ['orders.csv','reviews.csv', 'shipment_deliveries.csv' ]

#instantiate boto3 connection to s3 and check content of data lake
s3 = boto3.client('s3', config=Config(signature_version=UNSIGNED))

# %%
# download orders.csv
s3.download_file(bucket_name, 'orders_data/orders.csv', 'orders.csv')

# download reviews.csv
s3.download_file(bucket_name, 'orders_data/reviews.csv', 'reviews.csv')

#download shipment_deliveries.csv
s3.download_file(bucket_name, 'orders_data/shipment_deliveries.csv', 'shipment_deliveries.csv')

# %% [markdown]
# # Data Loading
#
# The script connects to a PostgreSQL database and loads the extracted data into the respective tables.

# %%
# To connect to Postgres SQL for the data load

# Connect to PG

pg_conn = {
    'host': '34.89.230.185',
    'dbname': 'd2b_accessment',
    'user': 'opeyadeg3905',
    'password': 'Omm6sSnmmo',
    'port': 5432
}

engine = create_engine(f"postgresql://{pg_conn['user']}:{pg_conn['password']}@{pg_conn['host']}:{pg_conn['port']}/{pg_conn['dbname']}")

# %%
# reads data from a CSV file named "orders.csv", stores it in the data list and then load into database

df = pd.read_csv("orders.csv")

data = []
with open("orders.csv", 'r') as f:
        reader = csv.reader(f)
        next(reader)
        for row in reader:
            data.append(row)
            
with psycopg2.connect(**pg_conn) as conn:
    with conn.cursor() as cur:
        for row in data:
            insert_query = f'INSERT INTO opeyadeg3905_staging.orders VALUES (%s, %s, %s, %s, %s, %s, %s)'
            cur.execute(insert_query, row)
            print(row)
    conn.commit()
# Out:
# ['1', '5', '2022-07-13', '24', '139', '10', '1390']
# ['2', '14', '2021-04-06', '2', '273', '4', '1092']
# ['3', '17', '2022-07-29', '20', '253', '9', '2277']
# ['4', '14', '2022-08-27', '8', '334', '1', '334']
# ['5', '25', '2021-12-15', '6', '334', '3', '1002']
# ['6', '7', '2021-04-15', '25', '144', '7', '1008']
# ['7', '4', '2021-09-28', '12', '876', '1', '876']
# ['8', '24', '2021-05-08', '15', '994', '7', '6958']
# ['9', '3', '2022-01-06', '18', '641', '4', '2564']
# ['10', '23', '2021-08-22', '3', '841', '5', '4205']
# ['11', '3', '2022-01-25', '8', '334', '8', '2672']
# ['12', '21', '2022-01-15', '12', '413', '4', '1652']
# ['13', '22', '2021-06-25', '9', '596', '4', '2384']
# ['14', '6', '2021-10-04', '15', '997', '9', '8973']
# ['15', '8', '2021-02-27', '22', '284', '1', '284']
# ['16', '11', '2021-03-09', '13', '266', '10', '2660']
# ['17', '23', '2022-05-27', '11', '455', '8', '3640']
# ['18', '5', '2021-09-10', '9', '812', '9', '7308']
# ...

# %%
# reads data from a CSV file named "reviews.csv", stores it in the data list and then load into database

df = pd.read_csv("reviews.csv")

data = []
with open("reviews.csv", 'r') as f:
        reader = csv.reader(f)
        next(reader)
        for row in reader:
            data.append(row)
            
with psycopg2.connect(**pg_conn) as conn:
    with conn.cursor() as cur:
        for row in data:
            insert_query = f'INSERT INTO opeyadeg3905_staging.reviews VALUES (%s, %s)'
            cur.execute(insert_query, row)
            print(row)
    conn.commit()
# Out:
# ['1', '21']
# ['3', '1']
# ['2', '8']
# ['1', '5']
# ['5', '22']
# ['5', '3']
# ['1', '14']
# ['1', '1']
# ['2', '7']
# ['5', '17']
# ['5', '1']
# ['5', '7']
# ['2', '14']
# ['5', '15']
# ['1', '9']
# ['2', '25']
# ['4', '23']
# ['3', '11']
# ['2', '5']
# ['3', '25']
# ['1', '4']
# ['1', '13']
# ['3', '12']
# ['3', '20']
# ['4', '2']
# ['1', '18']
# ['1', '13']
# ['3', '18']
# ['5', '21']
# ['5', '12']
# ['1', '7']
# ['2', '2']
# ['3', '25']
# ['2', '3']
# ['4', '4']
# ['4', '9']
# ['3', '21']
# ['3', '6']
# ['2', '12']
# ['3', '22']
# ['1', '23']
# ['2', '20']
# ['2', '18']
# ['4', '6']
# ['3', '13']
# ['5', '21']
# ['3', '8']
# ['1', '25']
# ['1', '8']
# ['4', '11']
# ['1', '9']
# ['5', '7']
# ['3', '23']
# ['4', '7']
# ['4', '13']
# ['3', '5']
# ['2', '5']
# ['5', '24']
# ['3', '18']
# ['5', '24']
# ['5', '14']
# ['3', '13']
# ['2', '8']
# ['4', '17']
# ['1', '3']
# ['2', '4']
# ['2', '21']
# ['4', '22']
# ['1', '20']
# ['4', '13']
# ['4', '20']
# ['3', '17']
# ['1', '18']
# ...

# %%
# reads data from a CSV file named "shipment_deliveries.csv", stores it in the data list and then load into database

df = pd.read_csv("shipment_deliveries.csv")

data = []
with open("shipment_deliveries.csv", 'r') as f:
        reader = csv.reader(f)
        next(reader)
        for row in reader:
            data.append(row)
            
with psycopg2.connect(**pg_conn) as conn:
    with conn.cursor() as cur:
        for row in data:
            processed_row = [None if value == '' else value for value in row]
            insert_query = f'INSERT INTO opeyadeg3905_staging.shipment_deliveries VALUES (%s, %s, %s, %s)'
            cur.execute(insert_query, processed_row)
            print(processed_row)
    conn.commit()
# Out:
# ['1', '1', '2022-07-14', None]
# ['2', '2', None, None]
# ['3', '3', '2022-07-31', '2022-08-03']
# ['4', '4', '2022-09-02', '2022-09-05']
# ['5', '5', '2021-12-19', '2021-12-20']
# ['6', '6', '2021-04-17', '2021-04-18']
# ['7', '7', None, None]
# ['8', '8', '2021-05-10', '2021-05-13']
# ['9', '9', None, None]
# ['10', '10', None, None]
# ['11', '11', None, None]
# ['12', '12', None, None]
# ['13', '13', '2021-07-01', '2021-07-03']
# ['14', '14', None, None]
# ['15', '15', '2021-03-02', '2021-03-03']
# ['16', '16', None, None]
# ['17', '17', None, None]
# ['18', '18', None, None]
# ['19', '19', None, None]
# ['20', '20', None, None]
# ['21', '21', '2021-04-27', None]
# ['22', '22', '2021-03-10', '2021-03-13']
# ['23', '23', None, None]
# ['24', '24', '2022-07-10', None]
# ['25', '25', '2021-05-01', '2021-05-02']
# ['26', '26', None, None]
# ['27', '27', '2022-06-08', '2022-06-10']
# ['28', '28', None, None]
# ['29', '29', None, None]
# ['30', '30', None, None]
# ...

# %% [markdown]
# #### This script connects to a PostgreSQL database specified by the pg_conn dictionary, creates an engine using SQLAlchemy, and loads the data into the corresponding tables using psycopg2 and pandas.
#
# #### The data loading process includes the following steps for each file:
#
# 1. Read the CSV file using pd.read_csv.
# 2. Extract the data from the CSV file and store it in a list.
# 3. Connect to the PostgreSQL database using psycopg2.
# 4. Insert each row of data into the respective table using cur.execute.
# 5. Print the inserted row for verification.
# 6. Commit the changes to the database.
